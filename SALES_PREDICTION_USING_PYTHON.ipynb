# %% [markdown]
# <a href="https://colab.research.google.com/github/RehanKhan-007/CODSOFT/blob/main/SALES_PREDICTION_USING_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('car_purchasing.csv',encoding='ISO-8859-1')

# %%
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns = ["customer name","customer e-mail","country","gender"],axis = 1,inplace = True)

# %%
X = df.drop("car purchase amount",axis = 1)
Y = df["car purchase amount"]

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
Y = scaler.fit_transform(Y.values.reshape(-1,1))

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = Sequential()

model.add(Dense(10,activation = 'relu',input_dim=4))
model.add(Dense(10,activation = 'relu'))
model.add(Dense(1,activation = 'linear'))

model.compile(optimizer = 'adam',loss = "mean_squared_error",metrics=["mean_absolute_error"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                50
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train,epochs = 50 , validation_split = 0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 27ms/step - loss: 0.1962 - mean_absolute_error: 0.4168 - val_loss: 0.1520 - val_mean_absolute_error: 0.3677
# Epoch 2/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1494 - mean_absolute_error: 0.3578 - val_loss: 0.1051 - val_mean_absolute_error: 0.3008
# Epoch 3/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1012 - mean_absolute_error: 0.2879 - val_loss: 0.0650 - val_mean_absolute_error: 0.2329
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0617 - mean_absolute_error: 0.2155 - val_loss: 0.0353 - val_mean_absolute_error: 0.1649
# Epoch 5/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0341 - mean_absolute_error: 0.1526 - val_loss: 0.0183 - val_mean_absolute_error: 0.1106
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0191 - mean_absolute_error: 0.1111 - val_loss: 0.0128 - val_mean_absolute_error: 0.0870
# Epoch 7/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0157 - mean_absolute_error: 0.0968 - val_loss: 0.0128 - val_mean_absolute_error: 0.0830
# Epoch 8/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0155 - mean_absolute_error: 0.0961 - val_loss: 0.0126 - val_mean_absolute_error: 0.0816
# Epoch 9/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0149 - mean_absolute_error: 0.0945 - val_loss: 0.0114 - val_mean_absolute_error: 0.0783
# Epoch 10/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0141 - mean_absolute_error: 0.0924 - val_loss: 0.0104 - val_mean_absolute_error: 0.0760
# Epoch 11/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0135 - mean_absolute_error: 0.0911 - val_loss: 0.0097 - val_mean_absolute_error: 0.0743
# Epoch 12/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0131 - mean_absolute_error: 0.0898 - val_loss: 0.0092 - val_mean_absolute_error: 0.0728
# Epoch 13/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0126 - mean_absolute_error: 0.0880 - val_loss: 0.0087 - val_mean_absolute_error: 0.0704
# Epoch 14/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mean_absolute_error: 0.0862 - val_loss: 0.0082 - val_mean_absolute_error: 0.0684
# Epoch 15/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mean_absolute_error: 0.0846 - val_loss: 0.0077 - val_mean_absolute_error: 0.0667
# Epoch 16/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mean_absolute_error: 0.0833 - val_loss: 0.0074 - val_mean_absolute_error: 0.0652
# Epoch 17/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0109 - mean_absolute_error: 0.0824 - val_loss: 0.0071 - val_mean_absolute_error: 0.0639
# Epoch 18/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0105 - mean_absolute_error: 0.0809 - val_loss: 0.0070 - val_mean_absolute_error: 0.0628
# Epoch 19/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0102 - mean_absolute_error: 0.0796 - val_loss: 0.0067 - val_mean_absolute_error: 0.0616
# Epoch 20/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0099 - mean_absolute_error: 0.0786 - val_loss: 0.0065 - val_mean_absolute_error: 0.0606
# Epoch 21/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0096 - mean_absolute_error: 0.0774 - val_loss: 0.0062 - val_mean_absolute_error: 0.0594
# Epoch 22/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_absolute_error: 0.0762 - val_loss: 0.0060 - val_mean_absolute_error: 0.0583
# Epoch 23/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_absolute_error: 0.0749 - val_loss: 0.0058 - val_mean_absolute_error: 0.0572
# Epoch 24/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0087 - mean_absolute_error: 0.0736 - val_loss: 0.0056 - val_mean_absolute_error: 0.0564
# Epoch 25/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0084 - mean_absolute_error: 0.0725 - val_loss: 0.0054 - val_mean_absolute_error: 0.0553
# Epoch 26/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0082 - mean_absolute_error: 0.0714 - val_loss: 0.0053 - val_mean_absolute_error: 0.0543
# Epoch 27/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0079 - mean_absolute_error: 0.0701 - val_loss: 0.0051 - val_mean_absolute_error: 0.0535
# Epoch 28/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0076 - mean_absolute_error: 0.0689 - val_loss: 0.0049 - val_mean_absolute_error: 0.0524
# Epoch 29/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0074 - mean_absolute_error: 0.0677 - val_loss: 0.0047 - val_mean_absolute_error: 0.0514
# Epoch 30/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0072 - mean_absolute_error: 0.0667 - val_loss: 0.0046 - val_mean_absolute_error: 0.0505
# Epoch 31/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0069 - mean_absolute_error: 0.0654 - val_loss: 0.0044 - val_mean_absolute_error: 0.0495
# Epoch 32/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0066 - mean_absolute_error: 0.0642 - val_loss: 0.0042 - val_mean_absolute_error: 0.0485
# Epoch 33/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0064 - mean_absolute_error: 0.0630 - val_loss: 0.0041 - val_mean_absolute_error: 0.0477
# Epoch 34/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0062 - mean_absolute_error: 0.0617 - val_loss: 0.0040 - val_mean_absolute_error: 0.0467
# Epoch 35/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0060 - mean_absolute_error: 0.0606 - val_loss: 0.0038 - val_mean_absolute_error: 0.0458
# Epoch 36/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0057 - mean_absolute_error: 0.0593 - val_loss: 0.0037 - val_mean_absolute_error: 0.0450
# Epoch 37/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0055 - mean_absolute_error: 0.0581 - val_loss: 0.0035 - val_mean_absolute_error: 0.0441
# Epoch 38/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0053 - mean_absolute_error: 0.0568 - val_loss: 0.0034 - val_mean_absolute_error: 0.0430
# Epoch 39/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0051 - mean_absolute_error: 0.0557 - val_loss: 0.0033 - val_mean_absolute_error: 0.0424
# Epoch 40/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0048 - mean_absolute_error: 0.0544 - val_loss: 0.0031 - val_mean_absolute_error: 0.0413
# Epoch 41/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0046 - mean_absolute_error: 0.0533 - val_loss: 0.0030 - val_mean_absolute_error: 0.0402
# Epoch 42/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0045 - mean_absolute_error: 0.0520 - val_loss: 0.0029 - val_mean_absolute_error: 0.0398
# Epoch 43/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0042 - mean_absolute_error: 0.0506 - val_loss: 0.0027 - val_mean_absolute_error: 0.0384
# Epoch 44/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0040 - mean_absolute_error: 0.0496 - val_loss: 0.0026 - val_mean_absolute_error: 0.0374
# Epoch 45/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0039 - mean_absolute_error: 0.0481 - val_loss: 0.0025 - val_mean_absolute_error: 0.0369
# Epoch 46/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0037 - mean_absolute_error: 0.0472 - val_loss: 0.0024 - val_mean_absolute_error: 0.0355
# Epoch 47/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0035 - mean_absolute_error: 0.0455 - val_loss: 0.0023 - val_mean_absolute_error: 0.0349
# Epoch 48/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_absolute_error: 0.0444 - val_loss: 0.0022 - val_mean_absolute_error: 0.0337
# Epoch 49/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0429 - val_loss: 0.0021 - val_mean_absolute_error: 0.0328
# Epoch 50/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0415 - val_loss: 0.0019 - val_mean_absolute_error: 0.0317

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
# Normalize the features
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Build a simple neural network model
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=X.shape[1]))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Train the model
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)

# Make predictions
y_pred = model.predict(x_test)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 24ms/step - loss: 0.2725 - mean_absolute_error: 0.4959 - val_loss: 0.2256 - val_mean_absolute_error: 0.4518
# Epoch 2/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2342 - mean_absolute_error: 0.4570 - val_loss: 0.1948 - val_mean_absolute_error: 0.4172
# Epoch 3/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2026 - mean_absolute_error: 0.4220 - val_loss: 0.1668 - val_mean_absolute_error: 0.3827
# Epoch 4/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1723 - mean_absolute_error: 0.3849 - val_loss: 0.1383 - val_mean_absolute_error: 0.3443
# Epoch 5/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1410 - mean_absolute_error: 0.3426 - val_loss: 0.1086 - val_mean_absolute_error: 0.3002
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1081 - mean_absolute_error: 0.2935 - val_loss: 0.0777 - val_mean_absolute_error: 0.2469
# Epoch 7/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0737 - mean_absolute_error: 0.2350 - val_loss: 0.0489 - val_mean_absolute_error: 0.1865
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0460 - mean_absolute_error: 0.1766 - val_loss: 0.0300 - val_mean_absolute_error: 0.1337
# Epoch 9/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0294 - mean_absolute_error: 0.1344 - val_loss: 0.0226 - val_mean_absolute_error: 0.1135
# Epoch 10/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0233 - mean_absolute_error: 0.1212 - val_loss: 0.0212 - val_mean_absolute_error: 0.1115
# Epoch 11/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0218 - mean_absolute_error: 0.1186 - val_loss: 0.0204 - val_mean_absolute_error: 0.1097
# Epoch 12/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0202 - mean_absolute_error: 0.1145 - val_loss: 0.0180 - val_mean_absolute_error: 0.1021
# Epoch 13/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0182 - mean_absolute_error: 0.1076 - val_loss: 0.0159 - val_mean_absolute_error: 0.0946
# Epoch 14/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0170 - mean_absolute_error: 0.1024 - val_loss: 0.0149 - val_mean_absolute_error: 0.0913
# Epoch 15/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0160 - mean_absolute_error: 0.0991 - val_loss: 0.0142 - val_mean_absolute_error: 0.0887
# Epoch 16/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0151 - mean_absolute_error: 0.0966 - val_loss: 0.0134 - val_mean_absolute_error: 0.0859
# Epoch 17/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0143 - mean_absolute_error: 0.0941 - val_loss: 0.0127 - val_mean_absolute_error: 0.0829
# Epoch 18/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0136 - mean_absolute_error: 0.0916 - val_loss: 0.0120 - val_mean_absolute_error: 0.0804
# Epoch 19/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0129 - mean_absolute_error: 0.0893 - val_loss: 0.0112 - val_mean_absolute_error: 0.0772
# Epoch 20/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0123 - mean_absolute_error: 0.0870 - val_loss: 0.0106 - val_mean_absolute_error: 0.0747
# Epoch 21/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mean_absolute_error: 0.0847 - val_loss: 0.0100 - val_mean_absolute_error: 0.0719
# Epoch 22/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0111 - mean_absolute_error: 0.0826 - val_loss: 0.0095 - val_mean_absolute_error: 0.0697
# Epoch 23/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0105 - mean_absolute_error: 0.0808 - val_loss: 0.0091 - val_mean_absolute_error: 0.0681
# Epoch 24/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0100 - mean_absolute_error: 0.0787 - val_loss: 0.0085 - val_mean_absolute_error: 0.0656
# Epoch 25/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0095 - mean_absolute_error: 0.0769 - val_loss: 0.0081 - val_mean_absolute_error: 0.0638
# Epoch 26/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0091 - mean_absolute_error: 0.0752 - val_loss: 0.0076 - val_mean_absolute_error: 0.0618
# Epoch 27/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0086 - mean_absolute_error: 0.0734 - val_loss: 0.0074 - val_mean_absolute_error: 0.0610
# Epoch 28/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0081 - mean_absolute_error: 0.0714 - val_loss: 0.0069 - val_mean_absolute_error: 0.0584
# Epoch 29/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0078 - mean_absolute_error: 0.0699 - val_loss: 0.0065 - val_mean_absolute_error: 0.0565
# Epoch 30/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0075 - mean_absolute_error: 0.0687 - val_loss: 0.0064 - val_mean_absolute_error: 0.0567
# Epoch 31/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0070 - mean_absolute_error: 0.0669 - val_loss: 0.0059 - val_mean_absolute_error: 0.0532
# Epoch 32/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0649 - val_loss: 0.0057 - val_mean_absolute_error: 0.0528
# Epoch 33/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_absolute_error: 0.0639 - val_loss: 0.0055 - val_mean_absolute_error: 0.0522
# Epoch 34/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0060 - mean_absolute_error: 0.0617 - val_loss: 0.0051 - val_mean_absolute_error: 0.0495
# Epoch 35/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0057 - mean_absolute_error: 0.0606 - val_loss: 0.0049 - val_mean_absolute_error: 0.0493
# Epoch 36/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0054 - mean_absolute_error: 0.0589 - val_loss: 0.0046 - val_mean_absolute_error: 0.0476
# Epoch 37/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0051 - mean_absolute_error: 0.0574 - val_loss: 0.0044 - val_mean_absolute_error: 0.0461
# Epoch 38/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0048 - mean_absolute_error: 0.0560 - val_loss: 0.0043 - val_mean_absolute_error: 0.0465
# Epoch 39/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0046 - mean_absolute_error: 0.0545 - val_loss: 0.0040 - val_mean_absolute_error: 0.0437
# Epoch 40/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0043 - mean_absolute_error: 0.0530 - val_loss: 0.0038 - val_mean_absolute_error: 0.0433
# Epoch 41/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0041 - mean_absolute_error: 0.0513 - val_loss: 0.0036 - val_mean_absolute_error: 0.0416
# Epoch 42/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0038 - mean_absolute_error: 0.0500 - val_loss: 0.0035 - val_mean_absolute_error: 0.0408
# Epoch 43/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0035 - mean_absolute_error: 0.0481 - val_loss: 0.0032 - val_mean_absolute_error: 0.0386
# Epoch 44/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0466 - val_loss: 0.0030 - val_mean_absolute_error: 0.0378
# Epoch 45/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0031 - mean_absolute_error: 0.0454 - val_loss: 0.0029 - val_mean_absolute_error: 0.0369
# Epoch 46/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0028 - mean_absolute_error: 0.0430 - val_loss: 0.0026 - val_mean_absolute_error: 0.0343
# Epoch 47/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0026 - mean_absolute_error: 0.0412 - val_loss: 0.0025 - val_mean_absolute_error: 0.0334
# Epoch 48/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0023 - mean_absolute_error: 0.0392 - val_loss: 0.0023 - val_mean_absolute_error: 0.0321
# Epoch 49/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0021 - mean_absolute_error: 0.0374 - val_loss: 0.0021 - val_mean_absolute_error: 0.0309
# Epoch 50/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0019 - mean_absolute_error: 0.0355 - val_loss: 0.0020 - val_mean_absolute_error: 0.0294
# 4/4 [==============================] - 0s 4ms/step

# %%
# Calculate R-squared (R2) score
R2 = r2_score(y_test, y_pred)
print("R2 Score =", R2)
# Out:
# R2 Score = 0.9263583486139046
